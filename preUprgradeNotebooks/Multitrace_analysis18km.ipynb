# %%
from scipy.io import netcdf
import numpy as np
from pylab import clf, plot, show, floor, ceil, imshow
import matplotlib.pyplot as plt 
#xlabel, ylabel, legend, savefig, colorbar, title, clim, pcolor, cm, contourf
import os
import csv
import sys
import glob
from IPython.display import display, Math, Latex
sys.path.append('/noc/users/am8e13/Python/python_functions/')
#from Variable_button import *

# %%
dx=36000
t = 60*60*24*360 #seconds in an year

# %%
# Bathy is 1 on land and 0 over sea
x="/scratch/general/am8e13/results18km"
os.chdir(x) 
file2read = netcdf.NetCDFFile("grid.nc",'r')
Depth=file2read.variables['Depth']
Depth=Depth[:]*1
bathy=file2read.variables['HFacC']
bathy=bathy[:]*1
bathy[bathy==0]=-1
bathy[bathy>0]=0
bathy[bathy==-1]=1

bathy1 = bathy[0,:,:]

# %%
# Multitracer Tracer analysis 
x="/scratch/general/am8e13/results2_multitrac18km//"
os.chdir(x)
file2read = netcdf.NetCDFFile("ptracers.nc",'r')
# Tracers
storeggaSmall=file2read.variables['storeggaSmall']
storeggaSmall=storeggaSmall[:]*1
storeggaBig=file2read.variables['storeggaBig']
storeggaBig=storeggaBig[:]*1
storeggaNorth=file2read.variables['storeggaNorth']
storeggaNorth=storeggaNorth[:]*1
traenadjupet=file2read.variables['traenadjupet']
traenadjupet=traenadjupet[:]*1
bearisland=file2read.variables['bearisland']
bearisland=bearisland[:]*1
andoya=file2read.variables['andoya']
andoya=andoya[:]*1

Y=file2read.variables['Y']
Y=Y[:]*1
Z=file2read.variables['Z']
Z=Z[:]*1
X=file2read.variables['X']
X=X[:]*1
I=file2read.variables['iter']
I=I[:]*1
days=file2read.variables['T']
days=days[:]*1

storeggaSmall_ave = sum(storeggaSmall,axis = 1)
storeggaBig_ave = sum(storeggaBig,axis = 1)
storeggaNorth_ave = sum(storeggaNorth,axis = 1)
traenadjupet_ave = sum(traenadjupet,axis = 1)
bearisland_ave = sum(bearisland, axis = 1)
andoya_ave = sum(andoya, axis = 1)

# %%
#  The simulations below show the behaviour of different passive tracers. 
#  Tracers correspond to the locations of known source of sediment.
#  These experiments are 40y long each, starting from a 770y spun up circulation.

# %%
# Storegga Mud-pond (small)
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*storeggaSmall_ave[10:,:,:].max()
vimin = 0
vimax = storeggaSmall_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,storeggaSmall_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)

# %%
# Storegga Mud-pond (big)
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*storeggaBig_ave[10:,:,:].max()
vimin = 0
vimax = storeggaBig_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,storeggaBig_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)

# %%
# Storegga North Flanck 
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*storeggaNorth_ave[10:,:,:].max()
vimin = 0
vimax = storeggaNorth_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,storeggaNorth_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)

# %%
# Traenadjupet mud pond
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*traenadjupet_ave[10:,:,:].max()
vimin = 0
vimax = traenadjupet_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,traenadjupet_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)

# %%
# Bear Island Fan
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*bearisland_ave[10:,:,:].max()
vimin = 0
vimax = bearisland_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,bearisland_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)

# %%
# Bear Island Fan
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*andoya_ave[10:,:,:].max()
vimin = 0
vimax = andoya_ave[10:,:,:].max()

for ax in axes.flat:
    cs = ax.contourf(X,Y,andoya_ave[i*7,:,:]+ bathyfig,100,vmin=vimin, vmax=vimax)
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*7)]-days[0])//t) +" years")
    i=i+1

fig.subplots_adjust(right=2.4,top=2)
