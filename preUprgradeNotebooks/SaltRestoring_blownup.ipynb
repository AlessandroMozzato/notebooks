# %%
from scipy.io import netcdf
import numpy as np
from pylab import clf, plot, show, floor, ceil, imshow
import matplotlib.pyplot as plt 

#xlabel, ylabel, legend, savefig, colorbar, title, clim, pcolor, cm, contourf
import os
import csv
import sys
import glob
from IPython.display import display, Math, Latex
#sys.path.append('/noc/users/am8e13/Python/python_functions/')
#from Variable_button import *

# %%
# Bathy is 1 on land and 0 over sea
x="/scratch/general/am8e13/results36km"
os.chdir(x) 
file2read = netcdf.NetCDFFile("grid.nc",'r')
Depth=file2read.variables['Depth']
Depth=Depth[:]*1
bathy=file2read.variables['HFacC']
bathy=bathy[:]*1
bathy[bathy==0]=-1
bathy[bathy>0]=0
bathy[bathy==-1]=1

bathy1 = bathy[0,:,:]

# %%
x="/scratch/general/am8e13/results2_blownup//"
os.chdir(x)                                                                                                                                                                                                                  
file2read = netcdf.NetCDFFile("state.nc",'r')
Y=file2read.variables['Y']
Y=Y[:]*1
S_pert=file2read.variables['S']
S_pert=S_pert[:]*1

file2read = netcdf.NetCDFFile("RBCS_ss.nc",'r')
RBCS_SLT=file2read.variables['RBCS_SLT']
RBCS_SLT=RBCS_SLT[:]*1

x="/scratch/general/am8e13/results2_multitrac36km/"
os.chdir(x)                                                                                                                                                                                                                  
file2read = netcdf.NetCDFFile("state.nc",'r')
Y=file2read.variables['Y']
Y=Y[:]*1
S_np=file2read.variables['S']
S_np=S_np[:]*1
Z=file2read.variables['Z']
Z=Z[:]*1
X=file2read.variables['X']
X=X[:]*1
I=file2read.variables['iter']
I=I[:]*1
days=file2read.variables['T']
days=days[:]*1


dx=36000
t = 60*60*24*360 #seconds in an year

# %%
S_np_tot = np.mean(S_np, axis = 0) # average over all times of non perturbed simulation
S_np_tot = np.mean(S_np_tot, axis = 0)

S_pert_tot = np.mean(S_pert, axis = 0) # average over all times of non perturbed simulation
S_pert_tot = np.mean(S_pert_tot, axis = 0)

RBCS_SLT_tot = np.mean(RBCS_SLT,axis=0)
RBCS_SLT_tot = np.mean(RBCS_SLT_tot,axis=0)

S_np_top_ave = np.mean(S_np,axis=0)
S_np_top_ave = np.mean(S_np_top_ave[35:45,:,:],axis=0)
S_pert_top = np.mean(S_pert[:,35:45,:,:],axis=1)

# %%
# Overall difference between non restoring run and restoring run
bathyfig = bathy1*(S_pert_tot - S_np_tot).max()
vimin = (S_pert_tot - S_np_tot ).min()
vimax = (S_pert_tot - S_np_tot ).max()
contourf(X,Y,S_pert_tot - S_np_tot + bathyfig,100)
colorbar()
subplots_adjust(right=2.4,top=2)

# %%
# Overall average of restoring effect
bathyfig = bathy1*(RBCS_SLT_tot).max()
vimin = (RBCS_SLT_tot).min()
vimax = (RBCS_SLT_tot).max()
contourf(X,Y,RBCS_SLT_tot + bathyfig,100)
colorbar()
subplots_adjust(right=2.4,top=2)

# %%
# Salt contentration evolution
fig, axes = plt.subplots(nrows=2, ncols=3)
i=0
bathyfig = bathy1*(S_pert_top - S_np_top_ave).max()

vimin = (S_pert_top - S_np_top_ave).min()
vimax = (S_pert_top - S_np_top_ave).max()
#print levels
for ax in axes.flat:
    cs = ax.contourf(X,Y,S_pert_top[i*6,:,:] - S_np_top_ave + bathyfig,100,vmin=vimin, vmax=vimax )
    fig.colorbar(cs, ax=ax)
    ax.set_title(""+str((days[(i*6)]-days[0])//t) +"years")
    i=i+1
#
fig.subplots_adjust(right=2.4,top=2)

# %%
S_quant = sum(S_pert,axis = 1)
S_quant = sum(S_quant,axis = 1)
S_quant = sum(S_quant,axis = 1)
plot(S_quant)

# %%
whos
# Out:
# Variable       Type                                 Data/Info
# -------------------------------------------------------------
# Depth          ndarray                              192x210: 40320 elems, type `float64`, 322560 bytes (315 kb)
# I              ndarray                              322: 322 elems, type `int32`, 1288 bytes
# Latex          type                                 <class 'IPython.core.display.Latex'>
# Math           type                                 <class 'IPython.core.display.Math'>
# RBCS_SLT       ndarray                              40x50x192x210: 80640000 elems, type `float32`, 322560000 bytes (307 Mb)
# RBCS_SLT_tot   ndarray                              192x210: 40320 elems, type `float32`, 161280 bytes (157 kb)
# S_np           ndarray                              322x50x192x210: 649152000 elems, type `float32`, 2596608000 bytes (2476 Mb)
# S_np_top_ave   ndarray                              192x210: 40320 elems, type `float32`, 161280 bytes (157 kb)
# S_np_tot       ndarray                              192x210: 40320 elems, type `float32`, 161280 bytes (157 kb)
# S_pert         ndarray                              31x50x192x210: 62496000 elems, type `float32`, 249984000 bytes (238 Mb)
# S_pert_top     ndarray                              31x192x210: 1249920 elems, type `float32`, 4999680 bytes (4 Mb)
# S_pert_tot     ndarray                              192x210: 40320 elems, type `float32`, 161280 bytes (157 kb)
# S_quant        ndarray                              31: 31 elems, type `float32`, 124 bytes
# X              ndarray                              210: 210 elems, type `float64`, 1680 bytes
# Y              ndarray                              192: 192 elems, type `float64`, 1536 bytes
# Z              ndarray                              50: 50 elems, type `float64`, 400 bytes
# ax             AxesSubplot                          Axes(1.73088,0.125;0.535294x0.852273)
# axes           ndarray                              2x3: 6 elems, type `object`, 48 bytes
# bathy          ndarray                              50x192x210: 2016000 elems, type `float64`, 16128000 bytes (15 Mb)
# bathy1         ndarray                              192x210: 40320 elems, type `float64`, 322560 bytes (315 kb)
# bathyfig       ndarray                              192x210: 40320 elems, type `float64`, 322560 bytes (315 kb)
# cs             matplotlib.contour.QuadContourSet    <matplotlib.contour.QuadC<...>stance at 0x2b05b789fb48>
# csv            module                               <module 'csv' from '/noc/<...>a/lib/python2.7/csv.pyc'>
# days           ndarray                              322: 322 elems, type `float64`, 2576 bytes
# dx             int                                  36000
# fig            Figure                               Figure(480x320)
# file2read      netcdf_file                          <scipy.io.netcdf.netcdf_f<...>object at 0x2b01cf204a50>
# glob           module                               <module 'glob' from '/noc<...>/lib/python2.7/glob.pyc'>
# i              int                                  6
# netcdf         module                               <module 'scipy.io.netcdf'<...>ges/scipy/io/netcdf.pyc'>
# os             module                               <module 'os' from '/noc/u<...>da/lib/python2.7/os.pyc'>
# t              int                                  31104000
# vimax          float32                              13.7419
# vimin          float32                              -0.0189667
# x              str                                  /scratch/general/am8e13/results2_multitrac36km/
