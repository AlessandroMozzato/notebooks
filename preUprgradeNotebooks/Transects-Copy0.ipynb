# %%
from scipy.io import netcdf
import numpy as np
from pylab import clf, plot, show, floor, ceil, imshow
import matplotlib.pyplot as plt 
#xlabel, ylabel, legend, savefig, colorbar, title, clim, pcolor, cm, contourf
import os
import csv
import sys
import glob
from IPython.display import display, Math, Latex
from mpl_toolkits.basemap import Basemap
sys.path.append('/noc/users/am8e13/Python/')
import komod
sys.path.append('/noc/users/am8e13/Python/PyNIO-1.4.0/')
import Nio
sys.path.append('/noc/users/am8e13/PyNGL-1.4.0/lib/python2.7/site-packages/PyNGL/')
import Ngl as Ngl

# %%
global Ngl 
dx=36000
t = 60*60*24*360 #seconds in an year

# %%
# Bathy is 1 on land and 0 over sea
x="/scratch/general/am8e13/results18km"
os.chdir(x) 
file2read = netcdf.NetCDFFile("grid.nc",'r')
Depth = file2read.variables['Depth']
Depth = Depth[:]*1
bathy = file2read.variables['HFacC']
bathy = bathy[:]*1
Zp1 = file2read.variables['Zp1']
Zp1 = Zp1[:]*1

bathy[bathy==0]=-1
bathy[bathy>0]=0
bathy[bathy==-1]=1

bathy1 = bathy[0,:,:]

# %%
x="/scratch/general/am8e13/results2_multitrac18km//"
os.chdir(x)
file2read = netcdf.NetCDFFile("state.nc",'r')
S=file2read.variables['S']
S=S[:]*1
V=file2read.variables['V']
V=V[:]*1
T=file2read.variables['Temp']
T=T[:]*1


Y=file2read.variables['Y']
Y=Y[:]*1
Z=file2read.variables['Z']
Z=Z[:]*1
X=file2read.variables['X']
X=X[:]*1
I=file2read.variables['iter']
I=I[:]*1
days=file2read.variables['T']
days=days[:]*1

# %%
# Arctic Transects
S_ave = np.mean(S,axis=0)
T_ave = np.mean(T,axis=0)

# %%
# Arctic Transects
bathy_2 = np.array(bathy[0,:,:])
bathy_2[30*2:120*2,125*2:126*2]=2

fig, (ax1, ax2) = plt.subplots(1,2)

ax1 = plt.subplot(1,3,1)
ax1.contourf(X,Y,bathy_2,10)

ax2 = plt.subplot(1,3,2)
im2 = ax2.contourf(Y[30*2:120*2],Z[0:42],S_ave[0:42,30*2:120*2,125*2]+bathy[0:42,30*2:120*2,125*2],20)
cbar2 = plt.colorbar(im2)

ax2 = plt.subplot(1,3,3)
im3 = ax2.contourf(Y[30*2:120*2],Z[0:42],T_ave[0:42,30*2:120*2,125*2]+bathy[0:42,30*2:120*2,125*2],20)
cbar3 = plt.colorbar(im3)

fig.subplots_adjust(right=3,top=1.6)

# %%
# Arctic Transects
bathy_3 = np.array(bathy[0,:,:])
bathy_3[72*2:73*2,:]=2

fig, (ax1, ax2) = plt.subplots(1,2)

ax1 = plt.subplot(1,3,1)
ax1.contourf(X,Y,bathy_3,10)

ax2 = plt.subplot(1,3,2)
im2 = ax2.contourf(X,Z[0:42],S_ave[0:42,72*2,:]+bathy[0:42,72*2,:],20)
cbar2 = plt.colorbar(im2)

ax2 = plt.subplot(1,3,3)
im3 = ax2.contourf(X,Z[0:42],T_ave[0:42,72*2,:]+bathy[0:42,72*2,:],20)
cbar3 = plt.colorbar(im3)

fig.subplots_adjust(right=3,top=1.6)

# %%
# Arctic Transects
bathy_4 = np.array(bathy[0,:,:])
bathy_4[60*2:77*2,76*2:77*2]=2

fig, (ax1, ax2) = plt.subplots(1,2)

ax1 = plt.subplot(1,3,1)
ax1.contourf(X,Y,bathy_4,10)

ax2 = plt.subplot(1,3,2)
im2 = ax2.contourf(Y[60*2:77*2],Z[0:42],S_ave[0:42,60*2:77*2,76*2]-bathy[0:42,60*2:77*2,76*2],20)
cbar2 = plt.colorbar(im2)

ax3 = plt.subplot(1,3,3)
im3 = ax3.contourf(Y[60*2:77*2],Z[0:42],T_ave[0:42,60*2:77*2,76*2]-bathy[0:42,60*2:77*2,76*2],20)
cbar3 = plt.colorbar(im3)

fig.subplots_adjust(right=3,top=1.6)

# %%
x="/scratch/general/am8e13/results2_Salt36km/"
os.chdir(x)                                                                                                                                                                                                                  
file2read = netcdf.NetCDFFile("state.nc",'r')
S_pert=file2read.variables['S']
S_pert=S_pert[:]*1

x="/scratch/general/am8e13/results2_blownupfull/"
os.chdir(x)                                                                                                                                                                                                                  
file2read = netcdf.NetCDFFile("state.nc",'r')
S_blown=file2read.variables['S']
S_blown=S_blown[:]*1

x="/scratch/general/am8e13/results2_multitrac36km/"
os.chdir(x)
file2read = netcdf.NetCDFFile("state.nc",'r')
S_np=file2read.variables['S']
S_np=S_np[:]*1

# %%
dZ = np.zeros(len(Z)-1)
dZ[:] = Z[0:len(Z)-1] - Z[1:len(Z)]
#plot(dZ)

# %%
S_pert_quant = sum(S_pert, axis=2)
S_pert_quant = sum(S_pert_quant, axis=2)
S_pert_quant_a = dot(S_pert_quant[:,0:49],dZ)
# S_pert_quant_a total salt volume in m3

S_blown_quant = sum(S_blown, axis=2)
S_blown_quant = sum(S_blown_quant, axis=2)
S_blown_quant_a = dot(S_blown_quant[:,0:49],dZ)

S_np_quant = sum(S_np, axis=2)
S_np_quant = sum(S_np_quant, axis=2)
S_np_quant_a = dot(S_np_quant[:,0:49],dZ)

S_input = np.array(S)
S_input[:,36:42,69:81,36:40]=100
S_input_quant = sum(S_input, axis=2)
S_input_quant = sum(S_input_quant, axis=2)
S_input_quant_a = dot(S_input_quant[:,0:49],dZ)

# %%
plt.plot(S_pert_quant_a,'r--',S_input_quant_a,'b',S_np_quant_a,'g',S_blown_quant_a,'b--')
# Out:
# [<matplotlib.lines.Line2D at 0x2b47e5f12b10>,
#  <matplotlib.lines.Line2D at 0x2b47e5f12690>,
#  <matplotlib.lines.Line2D at 0x2b47e5ee7110>,
#  <matplotlib.lines.Line2D at 0x2b47e5cf9cd0>]

# %%
x="/scratch/general/am8e13/results2_multitrac18km/"
os.chdir(x)
file2read = netcdf.NetCDFFile("state.nc",'r')
U=file2read.variables['V']
U=U[:]*1

# %%
#Vtave=np.mean(V[3,:,70:74,:],axis = 2)
#Vtave=np.array(V[30,:,:,:])
#Zp=Zp1[:]
#Vtave[Vtave==0]=np.nan
#Vzone=np.nansum(Vtave*dx,axis = 2)
#dz=Zp[0:len(Zp)-1]-Zp[1:len(Zp)]
#psi = np.zeros((len(Zp),len(Y)))
#for j in range(len(Y)):
#    for k in range(0,len(Zp)-1):
#        psi[k,j] = psi[k-1,j] + dz[k]*Vzone[k,j]
#y =Y/1000
#Psi=psi/10**6 #Convert to Sv 

shape(Vzone)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-dab51f92ef8a> in <module>()
#      12 #Psi=psi/10**6 #Convert to Sv
#      13
# ---> 14 shape(Vzone)
#
# NameError: name 'Vzone' is not defined

# %%
# Arctic Transects
bathy_3 = np.array(bathy[0,:,:])
bathy_3[72*2,:]=2

fig, (ax1, ax2) = plt.subplots(1,2)

ax1 = plt.subplot(1,3,1)
ax1.contourf(X,Y,bathy_3,10)

ax2 = plt.subplot(1,3,2)
im2 = ax2.contourf(X,Z[0:42],S_ave[0:42,72*2,:]+bathy[0:42,72*2,:],20)
cbar2 = plt.colorbar(im2)

Vtave=np.mean(U[10:20,:,72*2:73*2,:],axis = 0)
Zp=Zp1[:]
Vtave[Vtave==0]=np.nan
Vzone=np.nansum(Vtave*dx,axis = 1)
dz=Zp[0:len(Zp)-1]-Zp[1:len(Zp)]
psi = np.zeros((len(Zp),len(X)))
for j in range(len(X)):
    for k in range(0,len(Zp)-1):
        psi[k,j] = psi[k-1,j] + dz[k]*Vzone[k,j]
y =Y
Psi=psi/10**6 #Convert to Sv 
ax3 = plt.subplot(1,3,3)
im3 = ax3.contourf(X,Zp[0:50],Psi[0:50,:] ,10,cmap=cm.seismic) #Use b2r colourmap                                       
#im3.clim(-(np.nanmax(Psi)),np.nanmax(Psi)) # Put 0 to white   + bathy[:,72*2,:]*10                                     
cbar = plt.colorbar(im3)
title("MOC year "+str(I[0]/t))
xlabel('Distance (km)')
ylabel('Density')
cbar.ax.set_ylabel('Psi (sv)')
fig.subplots_adjust(right=3,top=1.6)
#x="/noc/users/hb1g13/Figures/"+Comp+"/"+OP
#os.chdir(x)
#y="MOC"+str(I[0]/t)+".png"
#savefig(y)
# clf()

# %%
contourf(X,Zp[0:50],Vzone[:,0:210] + bathy[:,72,:],20) #Use b2r colourmap                                       
 # Put 0 to white                                        
cbar = colorbar()
title("MOC year "+str(I[0]/t))
xlabel('Distance (km)')
ylabel('Density')
cbar.ax.set_ylabel('Psi (sv)')
print len(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-4080fdb84406> in <module>()
# ----> 1 contourf(X,Zp[0:50],Vzone[:,0:210] + bathy[:,72,:],20) #Use b2r colourmap
#       2  # Put 0 to white
#       3 cbar = colorbar()
#       4 title("MOC year "+str(I[0]/t))
#       5 xlabel('Distance (km)')
#
# ValueError: operands could not be broadcast together with shapes (50,210) (50,420)

# %%
x="/scratch/general/am8e13/noaa_climatology/"
os.chdir(x)
file2read = netcdf.NetCDFFile("s00_04.nc",'r')
s_oa=file2read.variables['s_oa']
s_oa=s_oa[:]*1
s_mn=file2read.variables['s_mn']
s_mn=s_mn[:]*1
s_an=file2read.variables['s_an']
s_an=s_an[:]*1
lon=file2read.variables['lon']
lon=lon[:]*1
lat=file2read.variables['lat']
lat=lat[:]*1
depth=file2read.variables['depth']
depth=depth[:]*1

# %%
s_an.shape
# Out:
# (1, 102, 120, 1440)

# %%
contourf(lon,lat,s_an[0,1,:,:],20)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b47bb68ffc8>

# %%
s_new = np.array(s_an)
s_new[s_new == 9.96921e+36] = 40
s_new[:,:,75,650:760]=50
contourf(s_new[0,1,:,:],20)#lon,lat,
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b450e158cb0>

# %%
s_new = np.array(s_an)
s_new[s_new == 9.96921e+36] =20
#s_new[:,:,75,650:750]=  
contourf(lon[670:760],-depth[0:80],s_new[0,0:80,75,670:760],20)#lon,lat,
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b4509b5f8c0>

# %%
#!/bin/python


"""Komod plot module 
Contain mostly set of wrapper functions for map plotting with Basemap.
Can be used with any 2D data, not necessarily MITgcm."""

import numpy as np
from mpl_toolkits.basemap import Basemap

def regbase(region):
	'''Takes name of the region and returns dictionary with
	information necessary for creation of the Basemap instance
    '''

	mapDict = {}

	if region == 'Arctic':
		mapDict['projection'] = 'npstere'
		mapDict['boundinglat'] = 60
		mapDict['lon_0'] = 0
		mapDict['resolution'] = 'l'

	return mapDict

def bp(lon, lat, data, region = 'Arctic', ptype = 'contourf', **kwargs):
    
    '''Basic Basemap plot function. Use coordinates (1d or 2d), data and name of the region
     as an input and plot data. Region defines in the "regbase" function.

     You can also provide any argument for matplotlib plotting functions.

     Usage:
         bp(lon, lat, data, region = 'Arctic', ptype = 'contourf', **kwargs)
     
     Input:
        lon 		- 2D or 1D array of longitudes
		lat 		- 2D or 1D array of latitudes
		data 		- 2D array of scalar data.
		region      - one of the predefined regions (for list of regions see the "regbase" function)
		ptype       - plot type (contour, contourf, pcolor, pcolormesh)
		**kwargs    - arguments for plotting functions

     Output:
        Basemap instance.
    '''
    
    mapDict = regbase(region)

    # Create Basemap instance
    if mapDict['projection'] == 'npstere':
    	m = Basemap(projection=mapDict['projection'],boundinglat=mapDict['boundinglat'],\
    		        lon_0=mapDict['lon_0'],resolution=mapDict['resolution'])
    
    # Check if we have proper number of dimensions for lon (and hopefully lat as well)
    if lon.shape.__len__() == 1:
    	lon, lat = np.meshgrid(lon, lat)
    elif lon.shape.__len__() > 2:
    	raise Exception("Coordinate variables (lon) has too many dimensions")
    
    # Convert lat/lon to map coordinates
    x, y = m(lon, lat)

    # Make the map look better
    m.fillcontinents(color='gray',lake_color='gray')
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    
    # Draw values on the map
    if ptype == 'contourf':
        cs = m.contourf(x,y,data,**kwargs)
    elif ptype == 'pcolormesh':
        cs = m.pcolormesh(x,y,data,**kwargs)
    elif ptype == 'contour':
        cs = m.contour(x,y,data,**kwargs)
    elif ptype == 'pcolor':
        cs = m.pcolor(x,y,data,**kwargs)
    else:
        raise Exception("Plot type not supported. Valid plot types are: contour, contourf, pcolor, pcolormesh ")
    
    return m

# %%
fig = figure(figsize=(7,7))
bp(lon, lat, s_new[0,0,:,:])

# %%
#!/bin/python


"""Komod plot module 
Contain mostly set of wrapper functions for map plotting with Basemap.
Can be used with any 2D data, not necessarily MITgcm."""

import numpy as np
from mpl_toolkits.basemap import Basemap

def regbase(region):
	'''Takes name of the region and returns dictionary with
	information necessary for creation of the Basemap instance
    '''

	mapDict = {}

	if region == 'Arctic':
		mapDict['projection'] = 'moll'
		mapDict['boundinglat'] = 60
		mapDict['lon_0'] = 0
		mapDict['resolution'] = 'l'

	return mapDict

def bp(lon, lat, data, region = 'Arctic', ptype = 'contourf', **kwargs):
    
    '''Basic Basemap plot function. Use coordinates (1d or 2d), data and name of the region
     as an input and plot data. Region defines in the "regbase" function.

     You can also provide any argument for matplotlib plotting functions.

     Usage:
         bp(lon, lat, data, region = 'Arctic', ptype = 'contourf', **kwargs)
     
     Input:
        lon 		- 2D or 1D array of longitudes
		lat 		- 2D or 1D array of latitudes
		data 		- 2D array of scalar data.
		region      - one of the predefined regions (for list of regions see the "regbase" function)
		ptype       - plot type (contour, contourf, pcolor, pcolormesh)
		**kwargs    - arguments for plotting functions

     Output:
        Basemap instance.
    '''
    
    mapDict = regbase(region)

    # Create Basemap instance
    if mapDict['projection'] == 'moll':
    	m = Basemap(projection=mapDict['projection'],boundinglat=mapDict['boundinglat'],\
    		        lon_0=mapDict['lon_0'],resolution=mapDict['resolution'])
    
    # Check if we have proper number of dimensions for lon (and hopefully lat as well)
   # if lon.shape.__len__() == 1:
   # 	lon, lat = np.meshgrid(lon, lat)
   # elif lon.shape.__len__() > 2:
   # 	raise Exception("Coordinate variables (lon) has too many dimensions")
    
    # Convert lat/lon to map coordinates
    x, y = m(lon, lat)

    # Make the map look better
    m.fillcontinents(color='gray',lake_color='gray')
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    
    # Draw values on the map
    if ptype == 'contourf':
        cs = m.contourf(x,y,data,**kwargs)
    elif ptype == 'pcolormesh':
        cs = m.pcolormesh(x,y,data,**kwargs)
    elif ptype == 'contour':
        cs = m.contour(x,y,data,**kwargs)
    elif ptype == 'pcolor':
        cs = m.pcolor(x,y,data,**kwargs)
    else:
        raise Exception("Plot type not supported. Valid plot types are: contour, contourf, pcolor, pcolormesh ")
    
    return m

# %%
komod.arctpl(lon, lat, s_new[0,0,:,:], region='FramStAnna')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-269f0570e733> in <module>()
# ----> 1 komod.arctpl(lon, lat, s_new[0,0,:,:], region='FramStAnna')
#
# /noc/users/am8e13/Python/komod/mitplot.py in arctpl(lon, lat, data, datamin, datamax, datastep, showfig, psname, colormap_name, start_color, end_color, vtitle, raster_fill, miss, levon, llevel, add_cyclic, region, minLon, maxLon, minLat, maxLat)
#     358
#     359         if add_cyclic==True:
# --> 360           lon = Ngl.add_cyclic(lon)
#     361           lat = Ngl.add_cyclic(lat)
#     362
#
# NameError: global name 'Ngl' is not defined

# %%
lon = Ngl.add_cyclic(lon)
# Out:
# add_cyclic: input must be a 2-dimensional array.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
 rlist            = Ngl.Resources()

# %%
whos
# Out:
# Variable          Type                                 Data/Info
# ----------------------------------------------------------------
# Basemap           type                                 <class 'mpl_toolkits.basemap.Basemap'>
# Depth             ndarray                              384x420: 161280 elems, type `float64`, 1290240 bytes (1 Mb)
# I                 ndarray                              38: 38 elems, type `int32`, 152 bytes
# Latex             type                                 <class 'IPython.core.display.Latex'>
# Math              type                                 <class 'IPython.core.display.Math'>
# Ngl               module                               <module 'Ngl' from '/noc/<...>-packages/PyNGL/Ngl.pyc'>
# Nio               module                               <module 'Nio' from '/noc/<...>-packages/PyNIO/Nio.pyc'>
# Psi               ndarray                              51x420: 21420 elems, type `float64`, 171360 bytes (167 kb)
# S                 ndarray                              38x50x384x420: 306432000 elems, type `float32`, 1225728000 bytes (1168 Mb)
# S_ave             ndarray                              50x384x420: 8064000 elems, type `float32`, 32256000 bytes (30 Mb)
# S_blown           ndarray                              233x50x192x210: 469728000 elems, type `float32`, 1878912000 bytes (1791 Mb)
# S_blown_quant     ndarray                              233x50: 11650 elems, type `float32`, 46600 bytes
# S_blown_quant_a   ndarray                              233: 233 elems, type `float64`, 1864 bytes
# S_input           ndarray                              38x50x384x420: 306432000 elems, type `float32`, 1225728000 bytes (1168 Mb)
# S_input_quant     ndarray                              38x50: 1900 elems, type `float32`, 7600 bytes
# S_input_quant_a   ndarray                              38: 38 elems, type `float64`, 304 bytes
# S_np              ndarray                              271x50x192x210: 546336000 elems, type `float32`, 2185344000 bytes (2084 Mb)
# S_np_quant        ndarray                              271x50: 13550 elems, type `float32`, 54200 bytes
# S_np_quant_a      ndarray                              271: 271 elems, type `float64`, 2168 bytes
# S_pert            ndarray                              361x50x192x210: 727776000 elems, type `float32`, 2911104000 bytes (2776 Mb)
# S_pert_quant      ndarray                              361x50: 18050 elems, type `float32`, 72200 bytes
# S_pert_quant_a    ndarray                              361: 361 elems, type `float64`, 2888 bytes
# T                 ndarray                              38x50x384x420: 306432000 elems, type `float32`, 1225728000 bytes (1168 Mb)
# T_ave             ndarray                              50x384x420: 8064000 elems, type `float32`, 32256000 bytes (30 Mb)
# U                 ndarray                              38x50x385x420: 307230000 elems, type `float32`, 1228920000 bytes (1171 Mb)
# V                 ndarray                              38x50x385x420: 307230000 elems, type `float32`, 1228920000 bytes (1171 Mb)
# Vtave             ndarray                              50x2x420: 42000 elems, type `float32`, 168000 bytes (164 kb)
# Vzone             ndarray                              50x420: 21000 elems, type `float32`, 84000 bytes
# X                 ndarray                              420: 420 elems, type `float64`, 3360 bytes
# Y                 ndarray                              384: 384 elems, type `float64`, 3072 bytes
# Z                 ndarray                              50: 50 elems, type `float64`, 400 bytes
# Zp                ndarray                              51: 51 elems, type `float64`, 408 bytes
# Zp1               ndarray                              51: 51 elems, type `float64`, 408 bytes
# ax1               AxesSubplot                          Axes(0.125,0.125;0.845588x1.475)
# ax2               AxesSubplot                          Axes(1.13971,0.125;0.676471x1.475)
# ax3               AxesSubplot                          Axes(2.15441,0.125;0.676471x1.475)
# bathy             ndarray                              50x384x420: 8064000 elems, type `float64`, 64512000 bytes (61 Mb)
# bathy1            ndarray                              384x420: 161280 elems, type `float64`, 1290240 bytes (1 Mb)
# bathy_2           ndarray                              384x420: 161280 elems, type `float64`, 1290240 bytes (1 Mb)
# bathy_3           ndarray                              384x420: 161280 elems, type `float64`, 1290240 bytes (1 Mb)
# bathy_4           ndarray                              384x420: 161280 elems, type `float64`, 1290240 bytes (1 Mb)
# bp                function                             <function bp at 0x2b44e2b109b0>
# cbar              matplotlib.colorbar.Colorbar         <matplotlib.colorbar.Colo<...>stance at 0x2b47bb56ae18>
# cbar2             matplotlib.colorbar.Colorbar         <matplotlib.colorbar.Colo<...>stance at 0x2b47bb277f80>
# cbar3             matplotlib.colorbar.Colorbar         <matplotlib.colorbar.Colo<...>stance at 0x2b47741393f8>
# csv               module                               <module 'csv' from '/noc/<...>a/lib/python2.7/csv.pyc'>
# dZ                ndarray                              49: 49 elems, type `float64`, 392 bytes
# days              ndarray                              38: 38 elems, type `float64`, 304 bytes
# depth             ndarray                              102: 102 elems, type `float32`, 408 bytes
# dx                int                                  36000
# dz                ndarray                              50: 50 elems, type `float64`, 400 bytes
# fig               Figure                               Figure(560x560)
# file2read         netcdf_file                          <scipy.io.netcdf.netcdf_f<...>object at 0x2b47e5afbf90>
# glob              module                               <module 'glob' from '/noc<...>/lib/python2.7/glob.pyc'>
# im2               matplotlib.contour.QuadContourSet    <matplotlib.contour.QuadC<...>stance at 0x2b47e5c722d8>
# im3               matplotlib.contour.QuadContourSet    <matplotlib.contour.QuadC<...>stance at 0x2b47bb368b90>
# j                 int                                  419
# k                 int                                  49
# komod             module                               <module 'komod' from '/no<...>thon/komod/__init__.pyc'>
# lat               ndarray                              120: 120 elems, type `float32`, 480 bytes
# lon               ndarray                              1440: 1440 elems, type `float32`, 5760 bytes
# netcdf            module                               <module 'scipy.io.netcdf'<...>ges/scipy/io/netcdf.pyc'>
# os                module                               <module 'os' from '/noc/u<...>da/lib/python2.7/os.pyc'>
# psi               ndarray                              51x420: 21420 elems, type `float64`, 171360 bytes (167 kb)
# regbase           function                             <function regbase at 0x2b47e634be60>
# rlist             Ngl.Resources                        <Ngl.Resources instance at 0x2b44f3c47710>
# s_an              ndarray                              1x102x120x1440: 17625600 elems, type `float32`, 70502400 bytes (67 Mb)
# s_mn              ndarray                              1x102x120x1440: 17625600 elems, type `float32`, 70502400 bytes (67 Mb)
# s_new             ndarray                              1x102x120x1440: 17625600 elems, type `float32`, 70502400 bytes (67 Mb)
# s_oa              ndarray                              1x102x120x1440: 17625600 elems, type `float32`, 70502400 bytes (67 Mb)
# t                 int                                  31104000
# x                 str                                  /scratch/general/am8e13/noaa_climatology/
# y                 ndarray                              384: 384 elems, type `float64`, 3072 bytes
